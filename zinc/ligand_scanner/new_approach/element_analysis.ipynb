# %%
ls
# Out:
# 21Nov_1_ligand_scanner_results_no_cross_talk.txt  Untitled.ipynb

# %%
results = eval(open('21Nov_1_ligand_scanner_results_no_cross_talk.txt').read())

# %%
results
# Out:
# {'CONECT_atoms': [('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#    3015,
#    'HIS222-NE2',
#    (7, 'nitrogen', 'N', 14.00672, 0.155)),
#   ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#    3015,
#    'HIS226-NE2',
#    (7, 'nitrogen', 'N', 14.00672, 0.155)),
#   ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#    3015,
#    'HIS232-NE2',
#    (7, 'nitrogen', 'N', 14.00672, 0.155)),
#   ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#    3015,
#    'CBP1-O1',
#    (8, 'oxygen', 'O', 15.99943, 0.152)),
#   ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#    3015,
#    'CBP1-N2',
#    (7, 'nitrogen', 'N', 14.00672, 0.155)),
#   ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#    3015,
#    'CBP1-O4',
#    (8, 'oxygen', 'O', 15.99943, 0.152)),
#   ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#    3016,
#    'HIS172-NE2',
#    (7, 'nitrogen', 'N', 14.00672, 0.155)),
#   ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#    3016,
#    'ASP174-OD2',
#    (8, 'oxygen', 'O', 15.99943, 0.152)),
# ...

# %%
conect_atoms = results['CONECT_atoms']

# %%
conect_atoms
# Out:
# [('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3015,
#   'HIS222-NE2',
#   (7, 'nitrogen', 'N', 14.00672, 0.155)),
#  ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3015,
#   'HIS226-NE2',
#   (7, 'nitrogen', 'N', 14.00672, 0.155)),
#  ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3015,
#   'HIS232-NE2',
#   (7, 'nitrogen', 'N', 14.00672, 0.155)),
#  ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3015,
#   'CBP1-O1',
#   (8, 'oxygen', 'O', 15.99943, 0.152)),
#  ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3015,
#   'CBP1-N2',
#   (7, 'nitrogen', 'N', 14.00672, 0.155)),
#  ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3015,
#   'CBP1-O4',
#   (8, 'oxygen', 'O', 15.99943, 0.152)),
#  ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3016,
#   'HIS172-NE2',
#   (7, 'nitrogen', 'N', 14.00672, 0.155)),
#  ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3016,
#   'ASP174-OD2',
#   (8, 'oxygen', 'O', 15.99943, 0.152)),
#  ('/cbio/jclab/share/pdb/56/pdb456c.ent.gz',
#   3016,
# ...

# %%
elements = []

for i in conect_atoms:
    elements.append(i[3])

# %%
elements
# Out:
# [(7, 'nitrogen', 'N', 14.00672, 0.155),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (8, 'oxygen', 'O', 15.99943, 0.152),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (8, 'oxygen', 'O', 15.99943, 0.152),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (8, 'oxygen', 'O', 15.99943, 0.152),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (8, 'oxygen', 'O', 15.99943, 0.152),
#  (8, 'oxygen', 'O', 15.99943, 0.152),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (8, 'oxygen', 'O', 15.99943, 0.152),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (8, 'oxygen', 'O', 15.99943, 0.152),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
#  (8, 'oxygen', 'O', 15.99943, 0.152),
#  (7, 'nitrogen', 'N', 14.00672, 0.155),
# ...

# %%
elements_symbols = []

for i in elements:
    elements_symbols.append(i[2])

# %%
elements_symbols
# Out:
# ['N',
#  'N',
#  'N',
#  'O',
#  'N',
#  'O',
#  'N',
#  'O',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'O',
#  'O',
#  'N',
#  'O',
#  'N',
#  'N',
#  'N',
#  'O',
#  'N',
#  'O',
#  'N',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'N',
#  'O',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'N',
#  'O',
#  'O',
#  'O',
#  'O',
#  'S',
#  'N',
#  'O',
#  'O',
#  'O',
#  'S',
#  'S',
#  'N',
#  'N',
#  'S',
#  'N',
#  'O',
#  'O',
#  'O',
#  'S',
#  'N',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'N',
#  'N',
#  'N',
#  'O',
#  'O',
#  'N',
#  'N',
#  'N',
#  'O',
#  'O',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'N',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'N',
#  'N',
#  'N',
#  'O',
#  'N',
#  'N',
#  'N',
#  'O',
#  'S',
#  'O',
#  'S',
# ...

# %%
from collections import Counter

# %%
Counter(elements_symbols)
# Out:
# Counter({'S': 38558, 'O': 38318, 'N': 33428, 'Cl': 220, 'Zn': 53, 'C': 45, 'P': 14, 'K': 10, 'F': 8, 'As': 6, 'Al': 6, 'U': 6, 'V': 5, 'Mg': 4, 'W': 2, 'Se': 2, 'I': 1, 'Br': 1, 'Na': 1})

# %%
sorted(Counter(elements_symbols).items(), key = lambda x: x[1], reverse = True)
# Out:
# [('S', 38558),
#  ('O', 38318),
#  ('N', 33428),
#  ('Cl', 220),
#  ('Zn', 53),
#  ('C', 45),
#  ('P', 14),
#  ('K', 10),
#  ('F', 8),
#  ('As', 6),
#  ('Al', 6),
#  ('U', 6),
#  ('V', 5),
#  ('Mg', 4),
#  ('W', 2),
#  ('Se', 2),
#  ('I', 1),
#  ('Br', 1),
#  ('Na', 1)]
