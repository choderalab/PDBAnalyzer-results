# %%
ls
# Out:
# PDB_elements.ipynb                                   pdblist_element_error.txt                            pdbx_conect_reader_openmm_results_elementerror.txt
# PDB_reader_elementcheck_results.txt                  pdblist_trues_files.txt                              pdbx_conect_reader_openmm_results_elementerror2.txt
# covale2_files.ipynb                                  pdbx_conect_reader_covale_files_results.txt          pdbx_conect_reader_openmm_results_trues.txt
# covale_analysis.ipynb                                pdbx_conect_reader_covale_results.txt                pdbxlist_covale.txt
# openmm_full_analysis.ipynb                           pdbx_conect_reader_openmm_results.txt                trues.ipynb

# %%
results = eval(open('PDB_reader_elementcheck_results.txt').read())

# %%
results
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %%
results2 = []

for i in results:
    if i:
        results2.append(i)

# %%
results2
# Out:
# [['/cbio/jclab/share/pdb/ew/pdb4ew4.ent.gz', 'UNK'],
#  ['/cbio/jclab/share/pdb/kp/pdb1kp0.ent.gz',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'ASX',
#   'ASX',
#   'ASX',
#   'ASX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
#   'GLX',
# ...

# %%
len(results2)
# Out:
# 13

# %%
residues = []

for i in results2:
    residues += i[1:]

# %%
set(residues)
# Out:
# {'ASX', 'GLX', 'UNK', 'UNL', 'UNX'}
