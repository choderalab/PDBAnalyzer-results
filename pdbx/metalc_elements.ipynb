# %%
ls
# Out:
# PDB_elements.ipynb                                   pdblist_element_error.txt                            pdbx_conect_reader_openmm_results_elementerror2.txt
# PDB_reader_elementcheck_results.txt                  pdblist_metalc.txt                                   pdbx_conect_reader_openmm_results_trues.txt
# covale2_files.ipynb                                  pdblist_trues_files.txt                              pdbx_conect_reader_results_metalc_files.txt
# covale_analysis.ipynb                                pdbx_conect_reader_covale_files_results.txt          pdbx_metalc_elements.txt
# metalc_elements.ipynb                                pdbx_conect_reader_covale_results.txt                pdbxlist_covale.txt
# metalc_files.ipynb                                   pdbx_conect_reader_openmm_results.txt                trues.ipynb
# openmm_full_analysis.ipynb                           pdbx_conect_reader_openmm_results_elementerror.txt   trues_pdbx_openmm_results.txt

# %%
results = eval(open('pdbx_metalc_elements.txt').read())

# %%
results
# Out:
# [['P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'Mg'],
#  ['Fe'],
#  ['P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'Mg',
#   'Mg',
#   'Mg',
#   'Mg',
#   'Mg'],
#  ['Fe'],
#  ['P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'Mg'],
#  ['Fe'],
#  ['Fe'],
#  ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'Mg'],
#  ['Fe'],
#  [],
#  ['P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
#   'P',
# ...

# %%
results2 = []

for i in results:
    for j in i:
        results2.append(j)

# %%
set(results2)
# Out:
# {'Ag',
#  'Al',
#  'As',
#  'Au',
#  'B',
#  'Ba',
#  'Be',
#  'Bi',
#  'Ca',
#  'Cd',
#  'Ce',
#  'Co',
#  'Cr',
#  'Cs',
#  'Cu',
#  'D',
#  'Dy',
#  'Er',
#  'Eu',
#  'Fe',
#  'Ga',
#  'Gd',
#  'Hg',
#  'Ho',
#  'I',
#  'In',
#  'Ir',
#  'K',
#  'Kr',
#  'La',
#  'Li',
#  'Lu',
#  'Mg',
#  'Mn',
#  'Mo',
#  'Na',
#  'Ne',
#  'Ni',
#  'Os',
#  'P',
#  'Pb',
#  'Pd',
#  'Pr',
#  'Pt',
#  'Rb',
#  'Re',
#  'Rh',
#  'Ru',
#  'Sb',
#  'Sc',
#  'Si',
#  'Sm',
#  'Sr',
#  'Ta',
#  'Tb',
#  'Te',
#  'Tl',
#  'U',
#  'V',
#  'W',
#  'Xe',
#  'Y',
#  'Yb',
#  'Zn'}

# %%
metals_in_pdbfile = ['Al','As','Ba','Ca','Cd','Ce','Co','Cs','Cu','Dy','Fe','Gd','Hg','Ho','In','Ir','K','Li','Mg',
        'Mn','Mo','Na','Ni','Pb','Pd','Pt','Rb','Rh','Ru','Sm','Sr','Te','Tl','V','W','Yb','Zn']

# %%
set(metals_in_pdbfile) - set(results2)
# Out:
# set()

# %%
a = set(results2) - set(metals_in_pdbfile)

# %%
remove_coz_covale = ['PR', 'RU', 'AG', 'BE', 'OS', 'LA', 'RE', 'LU', 'AU', 'GA', 'EU', 'CR', 'TB']

# %%
minus = list(a)

# %%
minus = [x.upper() for x in minus]

# %%
set(minus) - set(remove_coz_covale)
# Out:
# {'B',
#  'BI',
#  'D',
#  'ER',
#  'I',
#  'KR',
#  'NE',
#  'P',
#  'SB',
#  'SC',
#  'SI',
#  'TA',
#  'U',
#  'XE',
#  'Y'}

# %%
to_investigate = ['BI', 'ER', 'SB', 'SC', 'TA', 'U', 'Y']
