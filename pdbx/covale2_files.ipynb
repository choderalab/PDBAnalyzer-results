# %%
ls
# Out:
# Untitled.ipynb                               covale_analysis.ipynb                        pdbx_conect_reader_covale_files_results.txt  pdbx_conect_reader_covale_results.txt

# %%
results = eval(open('pdbx_conect_reader_covale_files_results.txt').read())

# %%
results
# Out:
# [['/cbio/jclab/share/pdbx/01/101d.cif.gz',
#   '/cbio/jclab/share/pdbx/01/101d.cif.gz',
#   '/cbio/jclab/share/pdbx/01/101d.cif.gz',
#   '/cbio/jclab/share/pdbx/01/101d.cif.gz'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz'],
#  ['/cbio/jclab/share/pdbx/07/207l.cif.gz'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %%
results2 = [x for x in results if x]

# %%
results2
# Out:
# [['/cbio/jclab/share/pdbx/01/101d.cif.gz',
#   '/cbio/jclab/share/pdbx/01/101d.cif.gz',
#   '/cbio/jclab/share/pdbx/01/101d.cif.gz',
#   '/cbio/jclab/share/pdbx/01/101d.cif.gz'],
#  ['/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#   '/cbio/jclab/share/pdbx/07/207d.cif.gz'],
#  ['/cbio/jclab/share/pdbx/07/207l.cif.gz'],
#  ['/cbio/jclab/share/pdbx/08/308d.cif.gz',
#   '/cbio/jclab/share/pdbx/08/308d.cif.gz'],
#  ['/cbio/jclab/share/pdbx/09/109m.cif.gz',
#   '/cbio/jclab/share/pdbx/09/109m.cif.gz'],
#  ['/cbio/jclab/share/pdbx/09/209d.cif.gz',
# ...

# %%
results3 = []

for i in results2:
    results3.append(i[0])

# %%
results3
# Out:
# ['/cbio/jclab/share/pdbx/01/101d.cif.gz',
#  '/cbio/jclab/share/pdbx/07/207d.cif.gz',
#  '/cbio/jclab/share/pdbx/07/207l.cif.gz',
#  '/cbio/jclab/share/pdbx/08/308d.cif.gz',
#  '/cbio/jclab/share/pdbx/09/109m.cif.gz',
#  '/cbio/jclab/share/pdbx/09/209d.cif.gz',
#  '/cbio/jclab/share/pdbx/0m/10mh.cif.gz',
#  '/cbio/jclab/share/pdbx/11/211d.cif.gz',
#  '/cbio/jclab/share/pdbx/11/411d.cif.gz',
#  '/cbio/jclab/share/pdbx/14/214d.cif.gz',
#  '/cbio/jclab/share/pdbx/17/417d.cif.gz',
#  '/cbio/jclab/share/pdbx/19/219d.cif.gz',
#  '/cbio/jclab/share/pdbx/19/319d.cif.gz',
#  '/cbio/jclab/share/pdbx/1g/11gs.cif.gz',
#  '/cbio/jclab/share/pdbx/21/421d.cif.gz',
#  '/cbio/jclab/share/pdbx/23/123d.cif.gz',
#  '/cbio/jclab/share/pdbx/23/223d.cif.gz',
#  '/cbio/jclab/share/pdbx/23/223l.cif.gz',
#  '/cbio/jclab/share/pdbx/23/323d.cif.gz',
#  '/cbio/jclab/share/pdbx/24/324d.cif.gz',
#  '/cbio/jclab/share/pdbx/26/326d.cif.gz',
#  '/cbio/jclab/share/pdbx/27/327d.cif.gz',
# ...

# %%
len(results3)
# Out:
# 27130

# %%
f = open('pdbxlist_covale.txt', 'w')

# %%
for i in
