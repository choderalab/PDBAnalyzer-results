# %%
ls
# Out:
# PDB_reader_elementcheck_results.txt                  pdbx_conect_reader_covale_files_results.txt          pdbx_conect_reader_openmm_results_trues.txt
# covale2_files.ipynb                                  pdbx_conect_reader_covale_results.txt                pdbxlist_covale.txt
# covale_analysis.ipynb                                pdbx_conect_reader_openmm_results.txt                trues.ipynb
# openmm_full_analysis.ipynb                           pdbx_conect_reader_openmm_results_elementerror.txt
# pdblist_element_error.txt                            pdbx_conect_reader_openmm_results_elementerror2.txt

# %%
results = eval(open('pdbx_conect_reader_openmm_results_trues.txt').read())

# %%
results
# Out:
# [[False],
#  [],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
# ...

# %%
trues_files = []

for i in results:
    if len(i) == 2:
        trues_files.append(i[1])

# %%
trues_files
# Out:
# ['/cbio/jclab/share/pdbx/ac/4ac6.cif.gz',
#  '/cbio/jclab/share/pdbx/ac/4acl.cif.gz',
#  '/cbio/jclab/share/pdbx/ao/1aoo.cif.gz',
#  '/cbio/jclab/share/pdbx/aw/2aw0.cif.gz',
#  '/cbio/jclab/share/pdbx/ax/4axx.cif.gz',
#  '/cbio/jclab/share/pdbx/b9/3b9b.cif.gz',
#  '/cbio/jclab/share/pdbx/be/1bex.cif.gz',
#  '/cbio/jclab/share/pdbx/be/2bef.cif.gz',
#  '/cbio/jclab/share/pdbx/br/1br4.cif.gz',
#  '/cbio/jclab/share/pdbx/c7/3c7n.cif.gz',
#  '/cbio/jclab/share/pdbx/cb/4cbq.cif.gz',
#  '/cbio/jclab/share/pdbx/co/1coh.cif.gz',
#  '/cbio/jclab/share/pdbx/d6/4d6y.cif.gz',
#  '/cbio/jclab/share/pdbx/di/3din.cif.gz',
#  '/cbio/jclab/share/pdbx/dr/1dr6.cif.gz',
#  '/cbio/jclab/share/pdbx/dr/1dr7.cif.gz',
#  '/cbio/jclab/share/pdbx/fk/2fka.cif.gz',
#  '/cbio/jclab/share/pdbx/fl/2flw.cif.gz',
#  '/cbio/jclab/share/pdbx/fn/2fnw.cif.gz',
#  '/cbio/jclab/share/pdbx/fq/1fqw.cif.gz',
#  '/cbio/jclab/share/pdbx/i5/1i53.cif.gz',
#  '/cbio/jclab/share/pdbx/ic/3ice.cif.gz',
# ...

# %%
len(trues_files)
# Out:
# 124

# %%
f = open('pdblist_trues_files.txt', 'w')

# %%
for i in trues_files:
    f.write(i)
    f.write("\n")

# %%
ls
# Out:
# PDB_elements.ipynb                                   openmm_full_analysis.ipynb                           pdbx_conect_reader_covale_results.txt                pdbx_conect_reader_openmm_results_trues.txt
# PDB_reader_elementcheck_results.txt                  pdblist_element_error.txt                            pdbx_conect_reader_openmm_results.txt                pdbxlist_covale.txt
# covale2_files.ipynb                                  pdblist_trues_files.txt                              pdbx_conect_reader_openmm_results_elementerror.txt   trues.ipynb
# covale_analysis.ipynb                                pdbx_conect_reader_covale_files_results.txt          pdbx_conect_reader_openmm_results_elementerror2.txt  trues_pdbx_openmm_results.txt

# %%
results_detail = eval(open('trues_pdbx_openmm_results.txt').read())

# %%
results_detail
# Out:
# [[['AU', 'AU', 'CYS', 'SG'], ['AU', 'AU', 'HIS', 'ND1']],
#  [['AU', 'AU', 'HIS', 'ND1'],
#   ['AU', 'AU', 'HIS', 'ND1'],
#   ['AU', 'AU', 'ASP', 'OD2'],
#   ['AU', 'AU', 'HIS', 'ND1']],
#  [['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG'],
#   ['AG', 'AG', 'CYS', 'SG']],
#  [['AG', 'AG', 'CYS', 'SG'], ['AG', 'AG', 'CYS', 'SG']],
#  [['3PG', 'O2', 'BEF', 'BE']],
#  [['ASP', 'OD2', 'BEF', 'BE']],
#  [['RBU', 'RU', 'HIS', 'NE2'], ['RBU', 'RU', 'HIS', 'NE2']],
#  [['BEF', 'BE', 'ADP', 'O3B'],
#   ['BEF', 'BE', 'ADP', 'O3B'],
#   ['BEF', 'BE', 'ADP', 'O3B']],
#  [['ADP', 'O3B', 'BEF', 'BE'],
#   ['ADP', 'O3B', 'BEF', 'BE'],
#   ['ADP', 'O3B', 'BEF', 'BE'],
#   ['ADP', 'O3B', 'BEF', 'BE']],
#  [['BEF', 'BE', 'ADP', 'O2B']],
# ...

# %%
results_detail2 = []

for i in results_detail:
    for j in i:
        results_detail2.append(j)

# %%
results_detail2
# Out:
# [['AU', 'AU', 'CYS', 'SG'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'ASP', 'OD2'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['3PG', 'O2', 'BEF', 'BE'],
#  ['ASP', 'OD2', 'BEF', 'BE'],
#  ['RBU', 'RU', 'HIS', 'NE2'],
#  ['RBU', 'RU', 'HIS', 'NE2'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['BEF', 'BE', 'ADP', 'O2B'],
#  ['AU', 'AU', 'CYS', 'SG'],
# ...

# %%
sameres = 0

for i in results_detail2:
    if i[0] == i[2]:
        sameres += 1

# %%
len(results_detail2)
# Out:
# 515

# %%
sameres
# Out:
# 4

# %%
for i in results_detail2:
    if i[0] == i[2]:
        print i
# Out:
# ['HEM', 'FE', 'HEM', 'C']
# ['RU', 'RU', 'RU', 'RU']
# ['RU', 'RU', 'RU', 'RU']
# ['RU', 'RU', 'RU', 'RU']

# %%
results_detail2
# Out:
# [['AU', 'AU', 'CYS', 'SG'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'ASP', 'OD2'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['3PG', 'O2', 'BEF', 'BE'],
#  ['ASP', 'OD2', 'BEF', 'BE'],
#  ['RBU', 'RU', 'HIS', 'NE2'],
#  ['RBU', 'RU', 'HIS', 'NE2'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['BEF', 'BE', 'ADP', 'O2B'],
#  ['AU', 'AU', 'CYS', 'SG'],
# ...

# %%
metals = ['BA',
 'YB',
 'EU',
 'FE',
 'DY',
 'V',
 'GA',
 'HG',
 'PR',
 'NI',
 'PT',
 'NA',
 'LI',
 'PB',
 'RE',
 'TL',
 'LU',
 'RU',
 'RB',
 'TE',
 'TB',
 'K',
 'ZN',
 'CO',
 'PD',
 'AG',
 'CA',
 'IR',
 'AL',
 'CD',
 'GD',
 'AU',
 'CE',
 'W',
 'IN',
 'CS',
 'CR',
 'CU',
 'MG',
 'SR',
 'MO',
 'MN',
 'SM',
 'OS',
 'HO',
 'AM',
 'LA',
 'SB',
 'TH',
 'AS',
 'BE',
 'RH']

# %%
one_atom_metals = []

for i in results_detail2:
    if i[0] in metals:
        one_atom_metals.append(i[0])
    if i [2] in metals:    
        one_atom_metals.append(i[2])

# %%
len(one_atom_metals)
# Out:
# 332

# %%
len(results_detail2)
# Out:
# 515

# %%
one_atom_metals
# Out:
# ['AU',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AU',
#  'AU',
#  'CR',
#  'CR',
#  'CR',
#  'LA',
#  'LA',
#  'LA',
#  'LA',
#  'LA',
#  'LA',
#  'GA',
#  'GA',
#  'GA',
#  'GA',
#  'GA',
#  'GA',
#  'LU',
#  'LU',
#  'LU',
#  'LU',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
#  'GA',
#  'GA',
#  'GA',
#  'GA',
#  'PR',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'PR',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
#  'AU',
# ...

# %%
from collections import Counter

# %%
Counter(one_atom_metals)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a083fe074e7> in <module>()
# ----> 1 Counter(one_atom_metals)
#
# NameError: name 'Counter' is not defined

# %%
set(results_detail2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-3090cb2d7758> in <module>()
# ----> 1 set(results_detail2)
#
# TypeError: unhashable type: 'list'

# %%
results_detail3 = []

for i in results_detail2:
    results_detail3.append(tuple(i))

# %%
results_detail3
# Out:
# [('AU', 'AU', 'CYS', 'SG'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AU', 'AU', 'ASP', 'OD2'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('3PG', 'O2', 'BEF', 'BE'),
#  ('ASP', 'OD2', 'BEF', 'BE'),
#  ('RBU', 'RU', 'HIS', 'NE2'),
#  ('RBU', 'RU', 'HIS', 'NE2'),
#  ('BEF', 'BE', 'ADP', 'O3B'),
#  ('BEF', 'BE', 'ADP', 'O3B'),
#  ('BEF', 'BE', 'ADP', 'O3B'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('BEF', 'BE', 'ADP', 'O2B'),
#  ('AU', 'AU', 'CYS', 'SG'),
# ...

# %%
set(results_detail3)
# Out:
# {('3PG', 'O2', 'BEF', 'BE'),
#  ('ADP', 'O1B', 'BEF', 'BE'),
#  ('ADP', 'O2B', 'BEF', 'BE'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('ADP', 'O3B', 'BF2', 'BE'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('ASN', 'OD1', 'TB', 'TB'),
#  ('ASP', 'OD1', 'BEF', 'BE'),
#  ('ASP', 'OD1', 'LA', 'LA'),
#  ('ASP', 'OD1', 'TB', 'TB'),
#  ('ASP', 'OD2', 'BEF', 'BE'),
#  ('ASP', 'OD2', 'LU', 'LU'),
#  ('ASP', 'OD2', 'TB', 'TB'),
#  ('AU', 'AU', 'ASP', 'OD2'),
#  ('AU', 'AU', 'CL', 'CL'),
#  ('AU', 'AU', 'CYS', 'SG'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AU', 'AU', 'HOH', 'O'),
#  ('AU', 'AU', 'LYS', 'O'),
#  ('AUC', 'AU', 'CYS', 'SG'),
#  ('BEF', 'BE', 'ADP', 'O2B'),
#  ('BEF', 'BE', 'ADP', 'O3B'),
#  ('BEF', 'BE', 'ASP', 'OD1'),
#  ('CMO', 'O', 'RU', 'RU'),
#  ('CR', 'CR', 'ASP', 'OD1'),
#  ('CR', 'CR', 'CZM', 'NA'),
#  ('CR', 'CR', 'CZM', 'NB'),
#  ('CR', 'CR', 'CZM', 'OA'),
#  ('CR', 'CR', 'CZM', 'OB'),
#  ('CR', 'CR', 'DT', 'OP1'),
#  ('CR', 'CR', 'HIS', 'NE2'),
#  ('CR', 'CR', 'HOH', 'O'),
# ...

# %%
set(one_atom_metals)
# Out:
# {'AG', 'AU', 'CR', 'EU', 'GA', 'LA', 'LU', 'OS', 'PR', 'RE', 'RU', 'TB'}

# %%
one_atom_metals_dict = {}

for i in one_atom_metals:
    one_atom_metals_dict[i] = []

# %%
for i in results_detail3:
    if i[0] in one_atom_metals_dict and i[2] in one_atom_metals_dict:
        pass
    elif i[0] in one_atom_metals_dict:
        one_atom_metals_dict[i[0]].append((i[2], i[3]))
    elif i[2] in one_atom_metals_dict:
        one_atom_metals_dict[i[2]].append((i[0], i[1]))

# %%
one_atom_metals_dict
# Out:
# {'AG': [('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('MET', 'SD'),
#   ('MET', 'SD'),
#   ('CYS', 'SG')],
#  'AU': [('CYS', 'SG'),
#   ('HIS', 'ND1'),
#   ('HIS', 'ND1'),
#   ('HIS', 'ND1'),
#   ('ASP', 'OD2'),
#   ('HIS', 'ND1'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CL', 'CL'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CL', 'CL'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
#   ('CYS', 'SG'),
# ...

# %%
one_atom_metals_dict_sets = {}
one_atom_metals_dict_counters = {}

for i in one_atom_metals_dict:
    one_atom_metals_dict_sets[i] = set(one_atom_metals_dict[i])
    one_atom_metals_dict_counters[i] = Counter(one_atom_metals_dict[i])

# %%
one_atom_metals_dict_sets
# Out:
# {'AG': {('CYS', 'SG'), ('MET', 'SD')},
#  'AU': {('ASP', 'OD2'),
#   ('CL', 'CL'),
#   ('CYS', 'SG'),
#   ('HIS', 'ND1'),
#   ('HOH', 'O'),
#   ('LYS', 'O')},
#  'CR': {('ASP', 'OD1'),
#   ('CZM', 'NA'),
#   ('CZM', 'NB'),
#   ('CZM', 'OA'),
#   ('CZM', 'OB'),
#   ('DT', 'OP1'),
#   ('DTP', 'O3B'),
#   ('HIS', 'NE2'),
#   ('HOH', 'O'),
#   ('MDN', 'O2'),
#   ('MDN', 'O6'),
#   ('TTE', 'O1A'),
#   ('TTE', 'O1G'),
#   ('TTE', 'O2B')},
#  'EU': {('EEU', 'N1'),
#   ('EEU', 'N2'),
#   ('EEU', 'N3'),
#   ('EEU', 'O3'),
#   ('EEU', 'O4'),
#   ('EEU', 'O5'),
#   ('EEU', 'O6')},
#  'GA': {('CYS', 'SG'),
#   ('EB4', 'O1'),
#   ('EB4', 'O2'),
#   ('EB4', 'O3'),
#   ('EB4', 'O4'),
#   ('EB4', 'O5'),
#   ('EB4', 'O6')},
#  'LA': {('ASN', 'OD1'),
#   ('ASP', 'O'),
#   ('ASP', 'OD1'),
#   ('ASP', 'OD2'),
#   ('GLU', 'OE1'),
#   ('GLU', 'OE2'),
#   ('HOH', 'O'),
#   ('ILE', 'O'),
#   ('THR', 'O'),
#   ('TYR', 'O')},
#  'LU': {('ASP', 'OD2')},
#  'OS': {('HIS', 'NE2')},
#  'PR': {('ACT', 'O'),
# ...

# %%
one_atom_metals_dict_counters
# Out:
# {'AG': Counter({('CYS', 'SG'): 29, ('MET', 'SD'): 2}),
#  'AU': Counter({('CYS', 'SG'): 26, ('HIS', 'ND1'): 4, ('HOH', 'O'): 3, ('CL', 'CL'): 2, ('LYS', 'O'): 1, ('ASP', 'OD2'): 1}),
#  'CR': Counter({('ASP', 'OD1'): 9, ('MDN', 'O2'): 2, ('TTE', 'O1A'): 2, ('TTE', 'O2B'): 2, ('DT', 'OP1'): 2, ('MDN', 'O6'): 2, ('TTE', 'O1G'): 2, ('CZM', 'OB'): 1, ('DTP', 'O3B'): 1, ('CZM', 'NB'): 1, ('CZM', 'OA'): 1, ('HOH', 'O'): 1, ('HIS', 'NE2'): 1, ('CZM', 'NA'): 1}),
#  'EU': Counter({('EEU', 'N1'): 1, ('EEU', 'O6'): 1, ('EEU', 'N2'): 1, ('EEU', 'O5'): 1, ('EEU', 'O3'): 1, ('EEU', 'N3'): 1, ('EEU', 'O4'): 1}),
#  'GA': Counter({('CYS', 'SG'): 16, ('EB4', 'O1'): 1, ('EB4', 'O2'): 1, ('EB4', 'O3'): 1, ('EB4', 'O4'): 1, ('EB4', 'O5'): 1, ('EB4', 'O6'): 1}),
#  'LA': Counter({('ASP', 'OD1'): 8, ('GLU', 'OE1'): 3, ('ASN', 'OD1'): 3, ('TYR', 'O'): 2, ('GLU', 'OE2'): 2, ('ASP', 'OD2'): 2, ('THR', 'O'): 1, ('HOH', 'O'): 1, ('ILE', 'O'): 1, ('ASP', 'O'): 1}),
#  'LU': Counter({('ASP', 'OD2'): 4}),
# ...

# %%
results_detail3
# Out:
# [('AU', 'AU', 'CYS', 'SG'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AU', 'AU', 'ASP', 'OD2'),
#  ('AU', 'AU', 'HIS', 'ND1'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('AG', 'AG', 'CYS', 'SG'),
#  ('3PG', 'O2', 'BEF', 'BE'),
#  ('ASP', 'OD2', 'BEF', 'BE'),
#  ('RBU', 'RU', 'HIS', 'NE2'),
#  ('RBU', 'RU', 'HIS', 'NE2'),
#  ('BEF', 'BE', 'ADP', 'O3B'),
#  ('BEF', 'BE', 'ADP', 'O3B'),
#  ('BEF', 'BE', 'ADP', 'O3B'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('ADP', 'O3B', 'BEF', 'BE'),
#  ('BEF', 'BE', 'ADP', 'O2B'),
#  ('AU', 'AU', 'CYS', 'SG'),
# ...

# %%
for i in results_detail3:
    if i[1] not in metals and i[3] not in metals:
        print i
# Out:
# ('CYS', 'SG', '0KA', 'AG1')
# ('CYS', 'SG', '0KA', 'AG1')
# ('RU0', 'RU1', 'HOH', 'O')

# %%
one_atom_metals = list(set(one_atom_metals))

# %%
one_atom_counts = {}
for i in one_atom_metals:
    one_atom_counts[i] = 0

# %%
for i in results_detail3:
    if i[1] in one_atom_counts:
        one_atom_counts[i[1]] += 1
    elif i[3] in one_atom_counts:
        one_atom_counts[i[3]] += 1

# %%
one_atom_counts
# Out:
# {'AG': 31,
#  'AU': 38,
#  'CR': 28,
#  'EU': 61,
#  'GA': 22,
#  'LA': 24,
#  'LU': 4,
#  'OS': 6,
#  'PR': 69,
#  'RE': 21,
#  'RU': 88,
#  'TB': 26}

# %%
results_detail2
# Out:
# [['AU', 'AU', 'CYS', 'SG'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'ASP', 'OD2'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['3PG', 'O2', 'BEF', 'BE'],
#  ['ASP', 'OD2', 'BEF', 'BE'],
#  ['RBU', 'RU', 'HIS', 'NE2'],
#  ['RBU', 'RU', 'HIS', 'NE2'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['BEF', 'BE', 'ADP', 'O2B'],
#  ['AU', 'AU', 'CYS', 'SG'],
# ...

# %%
all_metals_covale = []

for i in results_detail2:
    if i[1] in metals:
        all_metals_covale.append(i[1])
    if i[3] in metals:
        all_metals_covale.append(i[3])

# %%
len(all_metals_covale)
# Out:
# 516

# %%
len(results_detail2)
# Out:
# 515

# %%
Counter(all_metals_covale)
# Out:
# Counter({'RU': 91, 'BE': 87, 'PR': 69, 'EU': 61, 'AU': 38, 'AG': 31, 'CR': 28, 'TB': 26, 'LA': 24, 'GA': 22, 'RE': 21, 'OS': 6, 'FE': 5, 'LU': 4, 'HG': 2, 'NA': 1})

# %%
list(set(all_metals_covale))
# Out:
# ['PR',
#  'BE',
#  'TB',
#  'AG',
#  'RU',
#  'NA',
#  'LA',
#  'RE',
#  'LU',
#  'AU',
#  'FE',
#  'GA',
#  'EU',
#  'CR',
#  'OS',
#  'HG']

# %%
metals_covale_ligand_nos = {'RU': 91, 'BE': 87, 'PR': 69, 'EU': 61, 'AU': 38, 'AG': 31, 'CR': 28, 'TB': 26, 'LA': 24, 'GA': 22, 'RE': 21, 'OS': 6, 'FE': 5, 'LU': 4, 'HG': 2, 'NA': 1}

# %%
for i in results_detail2:
    if 'HG' in i:
        print i
# Out:
# ['CYS', 'SG', 'MBO', 'HG']
# ['CYS', 'SG', 'MBO', 'HG']

# %%
results_detail2
# Out:
# [['AU', 'AU', 'CYS', 'SG'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AU', 'AU', 'ASP', 'OD2'],
#  ['AU', 'AU', 'HIS', 'ND1'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['AG', 'AG', 'CYS', 'SG'],
#  ['3PG', 'O2', 'BEF', 'BE'],
#  ['ASP', 'OD2', 'BEF', 'BE'],
#  ['RBU', 'RU', 'HIS', 'NE2'],
#  ['RBU', 'RU', 'HIS', 'NE2'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['BEF', 'BE', 'ADP', 'O3B'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['ADP', 'O3B', 'BEF', 'BE'],
#  ['BEF', 'BE', 'ADP', 'O2B'],
#  ['AU', 'AU', 'CYS', 'SG'],
# ...

# %%
len(results_detail2)
# Out:
# 515

# %%
counter = 0

for i in results_detail2:
    if any([j in metals for j in i]):
        counter += 1

# %%
counter
# Out:
# 512

# %%
counter = 0

for i in results_detail2:
    if i[0] in metals or i[2] in metals:
        counter += 1

# %%
counter
# Out:
# 329

# %%
metals_covale = []

for i in results_detail2:
    for j in i:
        if j in metals:
            metals_covale.append(j)

# %%
from collections import Counter

# %%
Counter(metals_covale)
# Out:
# Counter({'RU': 169, 'PR': 138, 'BE': 87, 'AU': 75, 'EU': 68, 'AG': 62, 'CR': 56, 'TB': 52, 'LA': 48, 'GA': 44, 'RE': 25, 'LU': 8, 'OS': 8, 'FE': 5, 'HG': 2, 'NA': 1})

# %%
len(metals_covale)
# Out:
# 848

# %%
len(set(metals_covale))
# Out:
# 16
