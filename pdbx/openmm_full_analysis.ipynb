# %%
ls
# Out:
# covale2_files.ipynb                          openmm_full_analysis.ipynb                   pdbx_conect_reader_covale_results.txt        pdbxlist_covale.txt
# covale_analysis.ipynb                        pdbx_conect_reader_covale_files_results.txt  pdbx_conect_reader_openmm_results.txt

# %%
results = eval(open('pdbx_conect_reader_openmm_results.txt').read())

# %%
results
# Out:
# [[False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
# ...

# %%
len(results)
# Out:
# 114080

# %%
results2 = [x for x in results if x]

# %%
len(results2)
# Out:
# 113554

# %%
trues = 0
falses = 0
errors = 0

for i in results2:
    if i[0] == False:
        falses += 1
    elif i[0] == True:
        trues += 1
    else:
        errors += 1

# %%
trues
# Out:
# 128

# %%
falses
# Out:
# 112917

# %%
errors
# Out:
# 509

# %%
errors_list = []

for i in results2:
    if i[0] != True and i[0] != False:
        errors_list.append(i)

# %%
errors_list
# Out:
# [['/cbio/jclab/share/pdbx/a4/2a4k.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ab/3abk.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ab/3abl.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ab/3abm.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ag/3ag1.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ag/3ag2.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ag/3ag3.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ag/3ag4.cif.gz'],
#  ['/cbio/jclab/share/pdbx/aj/2ajp.cif.gz'],
#  ['/cbio/jclab/share/pdbx/am/2amx.cif.gz'],
#  ['/cbio/jclab/share/pdbx/am/3am2.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ao/2aoc.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ao/2aod.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ao/2aog.cif.gz'],
#  ['/cbio/jclab/share/pdbx/ar/2ar0.cif.gz'],
#  ['/cbio/jclab/share/pdbx/as/3asn.cif.gz'],
#  ['/cbio/jclab/share/pdbx/as/3aso.cif.gz'],
#  ['/cbio/jclab/share/pdbx/au/1au9.cif.gz'],
#  ['/cbio/jclab/share/pdbx/aw/2awp.cif.gz'],
#  ['/cbio/jclab/share/pdbx/b2/2b25.cif.gz'],
#  ['/cbio/jclab/share/pdbx/b6/2b6h.cif.gz'],
# ...

# %%
ls
# Out:
# covale2_files.ipynb                                 pdblist_element_error.txt                           pdbx_conect_reader_openmm_results.txt
# covale_analysis.ipynb                               pdbx_conect_reader_covale_files_results.txt         pdbx_conect_reader_openmm_results_elementerror.txt
# openmm_full_analysis.ipynb                          pdbx_conect_reader_covale_results.txt               pdbxlist_covale.txt

# %%
results2 = eval(open('pdbx_conect_reader_openmm_results_elementerror.txt').read())

# %%
results2
# Out:
# [['UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK'],
#  ['UNK', 'UNK'],
#  ['UNK', 'UNK'],
#  ['UNK', 'UNK'],
#  ['UNK', 'UNK'],
#  ['UNK', 'UNK'],
#  ['UNK', 'UNK'],
#  ['UNK', 'UNK'],
#  ['UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK',
#   'UNK'],
#  ['UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK'],
#  ['UNK', 'UNK', 'UNK'],
#  ['UNK'],
#  ['UNK'],
#  ['UNK'],
# ...

# %%
elements_results = []

for i in results2:
    for j in i:
        elements_results.append(j)

# %%
from collections import Counter

# %%
Counter(elements_results)
# Out:
# Counter({'UNK': 5964, 'XE2': 48, 'XE1': 48, 'XD1': 32, 'XD2': 32, 'X': 31, 'UNX': 22, 'X5': 2, 'X1': 2, 'X3': 2, 'X2': 2, 'X4': 2})

# %%
results_new = eval(open('pdbx_conect_reader_openmm_results_elementerror2.txt').read())

# %%
results_new
# Out:
# [['UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX'],
#  ['UNX', 'UNX'],
#  ['UNX', 'UNX'],
#  ['UNX', 'UNX'],
#  ['UNX', 'UNX'],
#  ['UNX', 'UNX'],
#  ['UNX', 'UNX'],
#  ['UNX', 'UNX'],
#  ['UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX',
#   'UNX'],
#  ['UNX', 'UNX', 'UNX', 'UNX', 'UNX', 'UNX'],
#  ['UNX', 'UNX', 'UNX'],
#  ['UNX'],
#  ['UNX'],
#  ['UNX'],
# ...

# %%
elements_residues = []

for i in results_new:
    for j in i:
        elements_residues.append(j)

# %%
Counter(elements_residues)
# Out:
# Counter({'UNX': 5974, 'GLX': 96, 'ASX': 64, 'UNL': 30, 'UNK': 23})
